# %%
import pandas as pd
import glob
import os
import sys

# %%
data2=pd.read_csv("subway_merge.csv", index_col=None, encoding='utf-8')
data2.head()
type(data2)
import datetime
# datetime.date(2016,1,1).isocalendar()[1:]
date=data2.iloc[:1000,0]
# type(date)
date5=data2.iloc[:1000,:]
date5.head()
# date.head()
data3=list(date)
#data3
#int('01')

# %%
datelist=[]
for i in range(len(data3)):
    date2=str(data3[i])
    year=date2[:4]
    month=date2[4:6]
    day=date2[6:8]
    da=datetime.date(int(year),int(month),int(day)).isocalendar()[1:]
    datelist.append(da)
datelist
date5["A"] = datelist
date5
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
#          사용일자       노선명   역ID          역명   승차총승객수  하차총승객수        등록일자       A
# 0    20150101       2호선   236       영등포구청   6199.0    6219  20151217.0  (1, 4)
# 1    20150101       2호선   237          당산   7982.0    8946  20151217.0  (1, 4)
# 2    20150101       2호선   238          합정  17406.0   15241  20151217.0  (1, 4)
# 3    20150101       2호선   239        홍대입구  57469.0   51756  20151217.0  (1, 4)
# 4    20150101       2호선   240          신촌  30115.0   27766  20151217.0  (1, 4)
# 5    20150101       2호선   241          이대  11553.0   12272  20151217.0  (1, 4)
# ...

# %%
datetime.date(2019,5,14).isocalendar()[1:]
# Out:
# (20, 2)

# %%
#grouped=date5["역명"].groupby(date5["A"])
means=date5["승하차"].groupby([date5["A"],date5["역명"]]).mean()
obj=pd.DataFrame(means)
obj
# df=pd.dataframe(means)
# df
# grouped2=grouped["승차총승객수"].groupby(grouped["역명"])
# grouped2.mean()
# Out:
#                     승하차
# A      역명
# (1, 4) 가능        7625.0
#        가락시장      5679.5
#        가산디지털단지  18764.0
#        가양       16544.0
#        가좌        2240.0
#        가천대       5844.0
#        가평        3846.0
#        간석        5988.0
#        갈매         177.0
#        강남       76949.0
#        강남구청      5903.5
#        강동       15877.0
#        강동구청      7957.0
#        강매        1263.0
#        강변       63563.0
#        강촌        1279.0
#        개롱        5119.0
#        개봉       22323.0
#        개포동       2915.0
#        개화        3098.0
#        개화산       5620.0
#        거여        6289.0
#        건대입구     39314.0
#        검암       16478.0
#        경마공원      1073.0
#        경복궁      22877.0
#        경찰병원      5086.0
#        계양        9186.0
#        고덕        6286.0
#        고려대       7863.0
# ...                 ...
# (1, 5) 팔당         809.0
#        평내호평     10312.0
#        평촌       27383.0
#        평택       26334.0
#        풍산        7077.0
#        하계       39574.0
# ...

# %%
date6=date5.iloc[:,4]
date7=date5.iloc[:,5]
listdate=list(date6+date7)
listdate
date5["승하차"]=listdate
date5
# for i in range(len(date5)):
#     print(date5[0])
#     type(date6)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#          사용일자       노선명   역ID          역명   승차총승객수  하차총승객수        등록일자  \
# 0    20150101       2호선   236       영등포구청   6199.0    6219  20151217.0
# 1    20150101       2호선   237          당산   7982.0    8946  20151217.0
# 2    20150101       2호선   238          합정  17406.0   15241  20151217.0
# 3    20150101       2호선   239        홍대입구  57469.0   51756  20151217.0
# 4    20150101       2호선   240          신촌  30115.0   27766  20151217.0
# 5    20150101       2호선   241          이대  11553.0   12272  20151217.0
# 6    20150101       2호선   242          아현   3510.0    3578  20151217.0
# ...
